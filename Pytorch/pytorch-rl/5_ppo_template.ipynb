# %% [markdown]
# # Hands-on Template: Proximal Policy Optimization / PPO
#
# Use the explanation notebook first:
#
# ```text
# 5 - Proximal Policy Optimization (PPO) [CartPole].ipynb
# ```
#
# Goal: implement the PPO data flow yourself.

# %% [markdown]
# ## 1) Imports and Setup

# %%
# %pip install -U "gymnasium[classic-control]"

import random
from collections import deque

import gymnasium as gym
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Categorical

SEED = 1234
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("device:", device)

# %% [markdown]
# ## 2) Environments

# %%
# TODO: create train_env and test_env with CartPole-v1
# train_env = ...
# test_env = ...

# TODO: seed action spaces

# TODO: inspect one reset
# state, info = ...
# print(state)
# print(train_env.observation_space)
# print(train_env.action_space)

# %% [markdown]
# ## 3) Actor-Critic Network

# %%
class ActorCritic(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super().__init__()
        # TODO: shared layer(s)
        # TODO: actor head outputs action logits
        # TODO: critic head outputs one value V(s)

    def forward(self, x):
        # TODO: compute shared features
        # TODO: compute logits
        # TODO: compute value and squeeze final dimension
        # TODO: return logits, value
        pass


# TODO: get dimensions from train_env
# INPUT_DIM = ...
# HIDDEN_DIM = 128
# OUTPUT_DIM = ...

# TODO: create policy and optimizer
# policy = ...
# optimizer = ...

# %% [markdown]
# ## 4) Collect One Episode
#
# Store old log probabilities because PPO compares the new policy to the old policy.

# %%
def collect_episode(env, policy, seed=None):
    # TODO: collect states, actions, old_log_probs, rewards, values, dones
    # TODO: sample actions from current policy
    # TODO: return tensors/lists plus episode_reward
    pass

# %% [markdown]
# ## 5) Returns and Advantages

# %%
def calculate_returns(rewards, discount_factor):
    # TODO: compute discounted returns
    pass


def calculate_advantages(returns, values, normalize=True):
    # TODO: advantages = returns - values.detach()
    # TODO: optionally normalize
    pass

# %% [markdown]
# ## 6) PPO Update
#
# Core idea:
#
# ```python
# ratio = torch.exp(new_log_probs - old_log_probs)
# unclipped = ratio * advantages
# clipped = torch.clamp(ratio, 1 - clip, 1 + clip) * advantages
# policy_loss = -torch.min(unclipped, clipped).mean()
# ```

# %%
def update_policy(policy, states, actions, old_log_probs, advantages, returns, optimizer, ppo_steps, ppo_clip):
    # TODO: detach old_log_probs, advantages, returns
    # TODO: for ppo_steps, recompute logits and values
    # TODO: compute new_log_probs
    # TODO: compute ratio
    # TODO: compute clipped PPO policy loss
    # TODO: compute value loss and entropy bonus
    # TODO: optimizer step
    pass

# %% [markdown]
# ## 7) Train One Episode With PPO

# %%
def train_one_episode(env, policy, optimizer, discount_factor, ppo_steps, ppo_clip, seed=None):
    # TODO: collect episode
    # TODO: calculate returns
    # TODO: calculate advantages
    # TODO: update policy
    # TODO: return losses and reward
    pass

# %% [markdown]
# ## 8) Evaluate

# %%
def evaluate(env, policy, seed=None):
    policy.eval()
    episode_reward = 0.0

    # TODO: reset env with seed
    # TODO: loop until terminated or truncated
    # TODO: use argmax action, not sampled action
    # TODO: accumulate reward

    return episode_reward

# %% [markdown]
# ## 9) Full Training Loop

# %%
MAX_EPISODES = 500
DISCOUNT_FACTOR = 0.99
PPO_STEPS = 5
PPO_CLIP = 0.2
N_TRIALS = 25
REWARD_THRESHOLD = 475
PRINT_EVERY = 10

train_rewards = []
test_rewards = []
recent_test_rewards = deque(maxlen=N_TRIALS)

for episode in range(1, MAX_EPISODES + 1):
    # TODO: train PPO episode
    # TODO: evaluate
    # TODO: track rewards and progress
    pass

# %% [markdown]
# ## 10) Plot

# %%
# TODO: plot train_rewards and test_rewards
# TODO: add labels, legend, grid, and reward threshold line

# %% [markdown]
# ## 11) Self-check
#
# Answer in comments:
#
# 1. What is the PPO ratio?
# 2. Why do we clip the ratio?
# 3. Why can PPO reuse the same rollout for multiple update steps?

# %%
# TODO: write answers here

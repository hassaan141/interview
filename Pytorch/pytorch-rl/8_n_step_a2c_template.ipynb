# %% [markdown]
# # Hands-on Template: n-step A2C
#
# Use the explanation notebook first:
#
# ```text
# 8 - n step A2C.ipynb
# ```
#
# Goal: implement short-rollout bootstrapping.

# %% [markdown]
# ## 1) Imports and Setup

# %%
# %pip install -U "gymnasium[classic-control]"

import random
from collections import deque

import gymnasium as gym
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Categorical

SEED = 1234
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("device:", device)

# %% [markdown]
# ## 2) Environments

# %%
# TODO: create train_env and test_env with CartPole-v1
# train_env = ...
# test_env = ...

# TODO: seed action spaces

# TODO: inspect one reset
# state, info = ...
# print(state)
# print(train_env.observation_space)
# print(train_env.action_space)

# %% [markdown]
# ## 3) Actor-Critic Network

# %%
class ActorCritic(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super().__init__()
        # TODO: shared layer(s)
        # TODO: actor head outputs action logits
        # TODO: critic head outputs one value V(s)

    def forward(self, x):
        # TODO: compute shared features
        # TODO: compute logits
        # TODO: compute value and squeeze final dimension
        # TODO: return logits, value
        pass


# TODO: get dimensions from train_env
# INPUT_DIM = ...
# HIDDEN_DIM = 128
# OUTPUT_DIM = ...

# TODO: create policy and optimizer
# policy = ...
# optimizer = ...

# %% [markdown]
# ## 4) Compute n-step Returns
#
# Use real rewards for `N_STEPS`, then bootstrap from critic value if the episode is not done.

# %%
def compute_n_step_returns(rewards, values, bootstrap_value, discount_factor):
    # TODO: walk backward from bootstrap_value
    # TODO: compute returns
    # TODO: advantages = returns - values.detach()
    # TODO: normalize advantages
    pass

# %% [markdown]
# ## 5) Collect Rollout

# %%
def collect_rollout(env, policy, state, n_steps):
    # TODO: collect up to n_steps transitions
    # TODO: return next state, done flag, log_probs, values, rewards, entropies, rollout_reward
    pass

# %% [markdown]
# ## 6) Update From Rollout

# %%
def update_from_rollout(log_probs, values, rewards, entropies, bootstrap_value, discount_factor, optimizer):
    # TODO: compute n-step returns and advantages
    # TODO: actor loss, critic loss, entropy bonus
    # TODO: optimizer step
    pass

# %% [markdown]
# ## 7) Train One Episode With n-step Updates

# %%
def train_one_episode(env, policy, optimizer, discount_factor, n_steps, seed=None):
    # TODO: reset env
    # TODO: repeatedly collect n-step rollouts until episode ends
    # TODO: bootstrap when episode is not done
    # TODO: update after each rollout
    pass

# %% [markdown]
# ## 8) Evaluate

# %%
def evaluate(env, policy, seed=None):
    policy.eval()
    episode_reward = 0.0

    # TODO: reset env with seed
    # TODO: loop until terminated or truncated
    # TODO: use argmax action, not sampled action
    # TODO: accumulate reward

    return episode_reward

# %% [markdown]
# ## 9) Full Training Loop

# %%
MAX_EPISODES = 500
DISCOUNT_FACTOR = 0.99
N_STEPS = 5
N_TRIALS = 25
REWARD_THRESHOLD = 475
PRINT_EVERY = 10

train_rewards = []
test_rewards = []
recent_test_rewards = deque(maxlen=N_TRIALS)

for episode in range(1, MAX_EPISODES + 1):
    # TODO: train one episode with n-step updates
    # TODO: evaluate
    # TODO: track rewards and progress
    pass

# %% [markdown]
# ## 10) Plot

# %%
# TODO: plot train_rewards and test_rewards
# TODO: add labels, legend, grid, and reward threshold line

# %% [markdown]
# ## 11) Self-check
#
# Answer in comments:
#
# 1. When is bootstrap value zero?
# 2. How is `N_STEPS = 1` different from full-episode return?
# 3. Why is n-step useful for scalable RL?

# %%
# TODO: write answers here
